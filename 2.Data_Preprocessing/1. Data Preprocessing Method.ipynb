# %%
#importing the Libraries#
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#Reading the Dataset#
dataset=pd.read_csv('customer_churn_prediction_dataset.csv')

# %%
# Only show 5 Rows for easy understanding
dataset
# Out:
#     customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0    0001-XXXX    Male              0     Yes        Yes       5           No
# 1    0002-XXXX  Female              0      No         No      42          Yes
# 2    0003-XXXX    Male              0      No         No      61          Yes
# 3    0004-XXXX    Male              1      No        Yes      22          Yes
# 4    0005-XXXX    Male              1     Yes        Yes      21           No
# ..         ...     ...            ...     ...        ...     ...          ...
# 295  0296-XXXX  Female              1      No        Yes      61           No
# 296  0297-XXXX  Female              0      No         No      49          Yes
# 297  0298-XXXX    Male              0      No        Yes      71          Yes
# 298  0299-XXXX    Male              1     Yes        Yes       1          Yes
# 299  0300-XXXX  Female              1     Yes        Yes      13          Yes
#
#         MultipleLines InternetService       OnlineSecurity  ...  \
# 0                 Yes              No                   No  ...
# 1    No phone service             DSL                  Yes  ...
# 2    No phone service              No                   No  ...
# 3                  No              No  No internet service  ...
# 4                  No             DSL                   No  ...
# ..                ...             ...                  ...  ...
# 295               Yes             DSL                   No  ...
# 296  No phone service             DSL  No internet service  ...
# 297               Yes             DSL  No internet service  ...
# 298               Yes              No                  Yes  ...
# 299               Yes             DSL  No internet service  ...
#
#         DeviceProtection          TechSupport          StreamingTV  \
# 0                     No                   No                   No
# 1                     No                   No  No internet service
# 2                     No                  Yes                  Yes
# 3                    Yes                   No  No internet service
# 4    No internet service                   No                   No
# ..                   ...                  ...                  ...
# 295                  Yes  No internet service                   No
# 296                  Yes  No internet service                  Yes
# 297                  Yes                  Yes                   No
# 298  No internet service  No internet service                  Yes
# 299                  Yes                   No  No internet service
#
#          StreamingMovies        Contract PaperlessBilling     PaymentMethod  \
# 0    No internet service  Month-to-month              Yes       Credit card
# 1    No internet service        Two year               No  Electronic check
# 2                     No        One year               No     Bank transfer
# 3                    Yes  Month-to-month               No  Electronic check
# 4    No internet service        One year               No     Bank transfer
# ..                   ...             ...              ...               ...
# 295                   No        One year              Yes  Electronic check
# 296                  Yes  Month-to-month              Yes      Mailed check
# 297                  Yes        Two year               No      Mailed check
# 298                  Yes        Two year               No       Credit card
# 299                  Yes  Month-to-month               No  Electronic check
#
#     MonthlyCharges  TotalCharges  Churn
# 0            27.43        137.15    Yes
# 1            38.28       1607.76    Yes
# 2           106.44       6492.84    Yes
# 3            92.49       2034.78     No
# 4            19.63        412.23    Yes
# ..             ...           ...    ...
# 295          42.52       2593.72     No
# 296          22.31       1093.19    Yes
# 297          59.57       4229.47    Yes
# 298          31.32         31.32     No
# 299          20.50        266.50    Yes
#
# [300 rows x 21 columns]

# %%
# To Check Balance or Imbalance Dataset
dataset["Churn"].value_counts()
# Out:
# No     161
# Yes    139
# Name: Churn, dtype: int64

# %%
# Information
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        300 non-null    object
#  1   gender            300 non-null    object
#  2   SeniorCitizen     300 non-null    int64
#  3   Partner           300 non-null    object
#  4   Dependents        300 non-null    object
#  5   tenure            300 non-null    int64
#  6   PhoneService      300 non-null    object
#  7   MultipleLines     300 non-null    object
#  8   InternetService   300 non-null    object
#  9   OnlineSecurity    300 non-null    object
#  10  OnlineBackup      300 non-null    object
#  11  DeviceProtection  300 non-null    object
#  12  TechSupport       300 non-null    object
#  13  StreamingTV       300 non-null    object
#  14  StreamingMovies   300 non-null    object
#  15  Contract          300 non-null    object
#  16  PaperlessBilling  300 non-null    object
#  17  PaymentMethod     300 non-null    object
#  18  MonthlyCharges    300 non-null    float64
#  19  TotalCharges      300 non-null    float64
#  20  Churn             300 non-null    object
# dtypes: float64(2), int64(2), object(17)
# memory usage: 49.3+ KB

# %%
# Check for null & nun values
#dataset.isna().sum() both are same code
dataset.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
# Data Type
dataset.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges        float64
# Churn                object
# dtype: object

# %%
dataset
# Out:
#     customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0    0001-XXXX    Male              0     Yes        Yes       5           No
# 1    0002-XXXX  Female              0      No         No      42          Yes
# 2    0003-XXXX    Male              0      No         No      61          Yes
# 3    0004-XXXX    Male              1      No        Yes      22          Yes
# 4    0005-XXXX    Male              1     Yes        Yes      21           No
# ..         ...     ...            ...     ...        ...     ...          ...
# 295  0296-XXXX  Female              1      No        Yes      61           No
# 296  0297-XXXX  Female              0      No         No      49          Yes
# 297  0298-XXXX    Male              0      No        Yes      71          Yes
# 298  0299-XXXX    Male              1     Yes        Yes       1          Yes
# 299  0300-XXXX  Female              1     Yes        Yes      13          Yes
#
#         MultipleLines InternetService       OnlineSecurity  ...  \
# 0                 Yes              No                   No  ...
# 1    No phone service             DSL                  Yes  ...
# 2    No phone service              No                   No  ...
# 3                  No              No  No internet service  ...
# 4                  No             DSL                   No  ...
# ..                ...             ...                  ...  ...
# 295               Yes             DSL                   No  ...
# 296  No phone service             DSL  No internet service  ...
# 297               Yes             DSL  No internet service  ...
# 298               Yes              No                  Yes  ...
# 299               Yes             DSL  No internet service  ...
#
#         DeviceProtection          TechSupport          StreamingTV  \
# 0                     No                   No                   No
# 1                     No                   No  No internet service
# 2                     No                  Yes                  Yes
# 3                    Yes                   No  No internet service
# 4    No internet service                   No                   No
# ..                   ...                  ...                  ...
# 295                  Yes  No internet service                   No
# 296                  Yes  No internet service                  Yes
# 297                  Yes                  Yes                   No
# 298  No internet service  No internet service                  Yes
# 299                  Yes                   No  No internet service
#
#          StreamingMovies        Contract PaperlessBilling     PaymentMethod  \
# 0    No internet service  Month-to-month              Yes       Credit card
# 1    No internet service        Two year               No  Electronic check
# 2                     No        One year               No     Bank transfer
# 3                    Yes  Month-to-month               No  Electronic check
# 4    No internet service        One year               No     Bank transfer
# ..                   ...             ...              ...               ...
# 295                   No        One year              Yes  Electronic check
# 296                  Yes  Month-to-month              Yes      Mailed check
# 297                  Yes        Two year               No      Mailed check
# 298                  Yes        Two year               No       Credit card
# 299                  Yes  Month-to-month               No  Electronic check
#
#     MonthlyCharges  TotalCharges  Churn
# 0            27.43        137.15    Yes
# 1            38.28       1607.76    Yes
# 2           106.44       6492.84    Yes
# 3            92.49       2034.78     No
# 4            19.63        412.23    Yes
# ..             ...           ...    ...
# 295          42.52       2593.72     No
# 296          22.31       1093.19    Yes
# 297          59.57       4229.47    Yes
# 298          31.32         31.32     No
# 299          20.50        266.50    Yes
#
# [300 rows x 21 columns]

# %%
datasets = dataset.drop(['customerID'],axis =1)
datasets
# Out:
#      gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0      Male              0     Yes        Yes       5           No
# 1    Female              0      No         No      42          Yes
# 2      Male              0      No         No      61          Yes
# 3      Male              1      No        Yes      22          Yes
# 4      Male              1     Yes        Yes      21           No
# ..      ...            ...     ...        ...     ...          ...
# 295  Female              1      No        Yes      61           No
# 296  Female              0      No         No      49          Yes
# 297    Male              0      No        Yes      71          Yes
# 298    Male              1     Yes        Yes       1          Yes
# 299  Female              1     Yes        Yes      13          Yes
#
#         MultipleLines InternetService       OnlineSecurity  \
# 0                 Yes              No                   No
# 1    No phone service             DSL                  Yes
# 2    No phone service              No                   No
# 3                  No              No  No internet service
# 4                  No             DSL                   No
# ..                ...             ...                  ...
# 295               Yes             DSL                   No
# 296  No phone service             DSL  No internet service
# 297               Yes             DSL  No internet service
# 298               Yes              No                  Yes
# 299               Yes             DSL  No internet service
#
#             OnlineBackup     DeviceProtection          TechSupport  \
# 0                    Yes                   No                   No
# 1                    Yes                   No                   No
# 2                    Yes                   No                  Yes
# 3    No internet service                  Yes                   No
# 4                     No  No internet service                   No
# ..                   ...                  ...                  ...
# 295  No internet service                  Yes  No internet service
# 296                   No                  Yes  No internet service
# 297                   No                  Yes                  Yes
# 298  No internet service  No internet service  No internet service
# 299  No internet service                  Yes                   No
#
#              StreamingTV      StreamingMovies        Contract  \
# 0                     No  No internet service  Month-to-month
# 1    No internet service  No internet service        Two year
# 2                    Yes                   No        One year
# 3    No internet service                  Yes  Month-to-month
# 4                     No  No internet service        One year
# ..                   ...                  ...             ...
# 295                   No                   No        One year
# 296                  Yes                  Yes  Month-to-month
# 297                   No                  Yes        Two year
# 298                  Yes                  Yes        Two year
# 299  No internet service                  Yes  Month-to-month
#
#     PaperlessBilling     PaymentMethod  MonthlyCharges  TotalCharges Churn
# 0                Yes       Credit card           27.43        137.15   Yes
# 1                 No  Electronic check           38.28       1607.76   Yes
# 2                 No     Bank transfer          106.44       6492.84   Yes
# 3                 No  Electronic check           92.49       2034.78    No
# 4                 No     Bank transfer           19.63        412.23   Yes
# ..               ...               ...             ...           ...   ...
# 295              Yes  Electronic check           42.52       2593.72    No
# 296              Yes      Mailed check           22.31       1093.19   Yes
# 297               No      Mailed check           59.57       4229.47   Yes
# 298               No       Credit card           31.32         31.32    No
# 299               No  Electronic check           20.50        266.50   Yes
#
# [300 rows x 20 columns]

# %%
# Find duplicate columns

df_T = datasets.T  # Transpose to check duplicate columns
duplicates = df_T.duplicated()

# Remove duplicate columns
dataset = datasets.loc[:, ~duplicates]

# Display removed columns
removed_cols = datasets.columns[duplicates]
print("Removed Duplicate Columns:", list(removed_cols))
# Out:
# Removed Duplicate Columns: []

# %%
dataset.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0    Male              0     Yes        Yes       5           No
# 1  Female              0      No         No      42          Yes
# 2    Male              0      No         No      61          Yes
# 3    Male              1      No        Yes      22          Yes
# 4    Male              1     Yes        Yes      21           No
#
#       MultipleLines InternetService       OnlineSecurity         OnlineBackup  \
# 0               Yes              No                   No                  Yes
# 1  No phone service             DSL                  Yes                  Yes
# 2  No phone service              No                   No                  Yes
# 3                No              No  No internet service  No internet service
# 4                No             DSL                   No                   No
#
#       DeviceProtection TechSupport          StreamingTV      StreamingMovies  \
# 0                   No          No                   No  No internet service
# 1                   No          No  No internet service  No internet service
# 2                   No         Yes                  Yes                   No
# 3                  Yes          No  No internet service                  Yes
# 4  No internet service          No                   No  No internet service
#
#          Contract PaperlessBilling     PaymentMethod  MonthlyCharges  \
# 0  Month-to-month              Yes       Credit card           27.43
# 1        Two year               No  Electronic check           38.28
# 2        One year               No     Bank transfer          106.44
# 3  Month-to-month               No  Electronic check           92.49
# 4        One year               No     Bank transfer           19.63
#
#    TotalCharges Churn
# 0        137.15   Yes
# 1       1607.76   Yes
# 2       6492.84   Yes
# 3       2034.78    No
# 4        412.23   Yes

# %%
# Split quan and qual values
def quanQual(dataset):
    quan=[]
    qual=[]
    for columnName in dataset.columns:
       # print(columnName)
        if(dataset[columnName].dtype=='O'):
            #print("qual")
            qual.append(columnName)
        else:
           # print("quan")
            quan.append(columnName)
    return quan,qual

# %%
quanQual(dataset)
# Out:
# (['SeniorCitizen', 'tenure', 'MonthlyCharges', 'TotalCharges'],
#  ['gender',
#   'Partner',
#   'Dependents',
#   'PhoneService',
#   'MultipleLines',
#   'InternetService',
#   'OnlineSecurity',
#   'OnlineBackup',
#   'DeviceProtection',
#   'TechSupport',
#   'StreamingTV',
#   'StreamingMovies',
#   'Contract',
#   'PaperlessBilling',
#   'PaymentMethod',
#   'Churn'])

# %%
quan,qual=quanQual (dataset)

# %%
quan
# Out:
# ['SeniorCitizen', 'tenure', 'MonthlyCharges', 'TotalCharges']

# %%
qual
# Out:
# ['gender',
#  'Partner',
#  'Dependents',
#  'PhoneService',
#  'MultipleLines',
#  'InternetService',
#  'OnlineSecurity',
#  'OnlineBackup',
#  'DeviceProtection',
#  'TechSupport',
#  'StreamingTV',
#  'StreamingMovies',
#  'Contract',
#  'PaperlessBilling',
#  'PaymentMethod',
#  'Churn']

# %%
# Inbuild Function
dataset.describe()
# Out:
#        SeniorCitizen      tenure  MonthlyCharges  TotalCharges
# count     300.000000  300.000000      300.000000    300.000000
# mean        0.543333   35.783333       67.226800   2477.975767
# std         0.498951   21.113400       28.638073   1918.540111
# min         0.000000    1.000000       18.450000     30.030000
# 25%         0.000000   17.000000       42.337500    910.302500
# 50%         1.000000   36.000000       68.635000   2072.400000
# 75%         1.000000   53.250000       92.430000   3618.405000
# max         1.000000   72.000000      118.640000   8318.880000

# %%
# For check these all
descriptive=pd.DataFrame(index=["Mean","Median","Mode","Q1:25%","Q2:50%","Q3:75%","99","Q4:100%","IQR",
                               "1.5Rule","Lesser","Greater","Min","Max"],columns=quan)
for coulmnName in quan:
    descriptive[coulmnName]["Mean"]=dataset[coulmnName].mean()
    descriptive[coulmnName]["Median"]=dataset[coulmnName].median()
    descriptive[coulmnName]["Mode"]=dataset[coulmnName].mode()[0]
    descriptive[coulmnName]["Q1:25%"]=dataset.describe()[coulmnName]["25%"]
    descriptive[coulmnName]["Q2:50%"]=dataset.describe()[coulmnName]["50%"]
    descriptive[coulmnName]["Q3:75%"]=dataset.describe()[coulmnName]["75%"]
    descriptive[coulmnName]["99"]=np.percentile(dataset[coulmnName],99)
    descriptive[coulmnName]["Q4:100%"]=dataset.describe()[coulmnName]["max"]
    descriptive[coulmnName]["IQR"]= descriptive[coulmnName]["Q3:75%"]-descriptive[coulmnName]["Q1:25%"]
    descriptive[coulmnName]["1.5Rule"]=1.5*descriptive[coulmnName]["IQR"]
    descriptive[coulmnName]["Lesser"]=descriptive[coulmnName]["Q1:25%"]-descriptive[coulmnName]["1.5Rule"]
    descriptive[coulmnName]["Greater"]=descriptive[coulmnName]["Q3:75%"]+ descriptive[coulmnName]["1.5Rule"]
    descriptive[coulmnName]["Min"]=dataset[coulmnName].min()
    descriptive[coulmnName]["Max"]=dataset[coulmnName].max()

# %%
descriptive
# Out:
#         SeniorCitizen     tenure MonthlyCharges TotalCharges
# Mean         0.543333  35.783333        67.2268  2477.975767
# Median            1.0       36.0         68.635       2072.4
# Mode                1         26          42.52       2154.8
# Q1:25%            0.0       17.0        42.3375     910.3025
# Q2:50%            1.0       36.0         68.635       2072.4
# Q3:75%            1.0      53.25          92.43     3618.405
# 99                1.0       72.0       118.3611    7469.4231
# Q4:100%           1.0       72.0         118.64      8318.88
# IQR               1.0      36.25        50.0925    2708.1025
# 1.5Rule           1.5     54.375       75.13875   4062.15375
# Lesser           -1.5    -37.375      -32.80125  -3151.85125
# Greater           2.5    107.625      167.56875   7680.55875
# Min                 0          1          18.45        30.03
# Max                 1         72         118.64      8318.88

# %%
# Check Outliers values
def outliear_check(quan, descriptive):
    Lesser = []
    Greater = []
    for columnName in quan:
        if descriptive[columnName]["Min"] < descriptive[columnName]["Lesser"]:
            Lesser.append(columnName)
        if descriptive[columnName]["Max"] > descriptive[columnName]["Greater"]:
            Greater.append(columnName)
    return Lesser, Greater

# %%
Lesser,Greater=  outliear_check(quan, descriptive)

# %%
Lesser
# Out:
# []

# %%
Greater
# Out:
# ['TotalCharges']

# %%
# Replace the Outliers (Model 2)
for columnName in Lesser:
        dataset[columnName][dataset[columnName]<descriptive[columnName]["Lesser"]]=descriptive[columnName]["Lesser"]
for columnName in Greater:
        dataset[columnName][dataset[columnName]>descriptive[columnName]["Greater"]]=descriptive[columnName]["Greater"]
# Out:
# C:\Users\anandha rishi\AppData\Local\Temp\ipykernel_6444\3764343087.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset[columnName][dataset[columnName]>descriptive[columnName]["Greater"]]=descriptive[columnName]["Greater"]

# %%
# For check these all
descriptive=pd.DataFrame(index=["Mean","Median","Mode","Q1:25%","Q2:50%","Q3:75%","99","Q4:100%","IQR",
                               "1.5Rule","Lesser","Greater","Min","Max"],columns=quan)
for coulmnName in quan:
    descriptive[coulmnName]["Mean"]=dataset[coulmnName].mean()
    descriptive[coulmnName]["Median"]=dataset[coulmnName].median()
    descriptive[coulmnName]["Mode"]=dataset[coulmnName].mode()[0]
    descriptive[coulmnName]["Q1:25%"]=dataset.describe()[coulmnName]["25%"]
    descriptive[coulmnName]["Q2:50%"]=dataset.describe()[coulmnName]["50%"]
    descriptive[coulmnName]["Q3:75%"]=dataset.describe()[coulmnName]["75%"]
    descriptive[coulmnName]["99"]=np.percentile(dataset[coulmnName],99)
    descriptive[coulmnName]["Q4:100%"]=dataset.describe()[coulmnName]["max"]
    descriptive[coulmnName]["IQR"]= descriptive[coulmnName]["Q3:75%"]-descriptive[coulmnName]["Q1:25%"]
    descriptive[coulmnName]["1.5Rule"]=1.5*descriptive[coulmnName]["IQR"]
    descriptive[coulmnName]["Lesser"]=descriptive[coulmnName]["Q1:25%"]-descriptive[coulmnName]["1.5Rule"]
    descriptive[coulmnName]["Greater"]=descriptive[coulmnName]["Q3:75%"]+ descriptive[coulmnName]["1.5Rule"]
    descriptive[coulmnName]["Min"]=dataset[coulmnName].min()
    descriptive[coulmnName]["Max"]=dataset[coulmnName].max()

# %%
descriptive
# Out:
#         SeniorCitizen     tenure MonthlyCharges TotalCharges
# Mean         0.543333  35.783333        67.2268  2473.449621
# Median            1.0       36.0         68.635       2072.4
# Mode                1         26          42.52   7680.55875
# Q1:25%            0.0       17.0        42.3375     910.3025
# Q2:50%            1.0       36.0         68.635       2072.4
# Q3:75%            1.0      53.25          92.43     3618.405
# 99                1.0       72.0       118.3611  7468.274287
# Q4:100%           1.0       72.0         118.64   7680.55875
# IQR               1.0      36.25        50.0925    2708.1025
# 1.5Rule           1.5     54.375       75.13875   4062.15375
# Lesser           -1.5    -37.375      -32.80125  -3151.85125
# Greater           2.5    107.625      167.56875   7680.55875
# Min                 0          1          18.45        30.03
# Max                 1         72         118.64   7680.55875

# %%
# Replace after again check outliers values
def outliear_check(quan, descriptive):
    Lesser = []
    Greater = []
    for columnName in quan:
        if descriptive[columnName]["Min"] < descriptive[columnName]["Lesser"]:
            Lesser.append(columnName)
        if descriptive[columnName]["Max"] > descriptive[columnName]["Greater"]:
            Greater.append(columnName)
    return Lesser, Greater

# %%
Lesser,Greater=  outliear_check(quan, descriptive)

# %%
Lesser
# Out:
# []

# %%
Greater
# Out:
# []

# %%
df = pd.DataFrame(dataset,columns = quan)

# %%
df
# Out:
#      SeniorCitizen  tenure  MonthlyCharges  TotalCharges
# 0                0       5           27.43        137.15
# 1                0      42           38.28       1607.76
# 2                0      61          106.44       6492.84
# 3                1      22           92.49       2034.78
# 4                1      21           19.63        412.23
# ..             ...     ...             ...           ...
# 295              1      61           42.52       2593.72
# 296              0      49           22.31       1093.19
# 297              0      71           59.57       4229.47
# 298              1       1           31.32         31.32
# 299              1      13           20.50        266.50
#
# [300 rows x 4 columns]

# %%
dff = pd.DataFrame(dataset,columns = qual)

# %%
dff
# Out:
#      gender Partner Dependents PhoneService     MultipleLines InternetService  \
# 0      Male     Yes        Yes           No               Yes              No
# 1    Female      No         No          Yes  No phone service             DSL
# 2      Male      No         No          Yes  No phone service              No
# 3      Male      No        Yes          Yes                No              No
# 4      Male     Yes        Yes           No                No             DSL
# ..      ...     ...        ...          ...               ...             ...
# 295  Female      No        Yes           No               Yes             DSL
# 296  Female      No         No          Yes  No phone service             DSL
# 297    Male      No        Yes          Yes               Yes             DSL
# 298    Male     Yes        Yes          Yes               Yes              No
# 299  Female     Yes        Yes          Yes               Yes             DSL
#
#           OnlineSecurity         OnlineBackup     DeviceProtection  \
# 0                     No                  Yes                   No
# 1                    Yes                  Yes                   No
# 2                     No                  Yes                   No
# 3    No internet service  No internet service                  Yes
# 4                     No                   No  No internet service
# ..                   ...                  ...                  ...
# 295                   No  No internet service                  Yes
# 296  No internet service                   No                  Yes
# 297  No internet service                   No                  Yes
# 298                  Yes  No internet service  No internet service
# 299  No internet service  No internet service                  Yes
#
#              TechSupport          StreamingTV      StreamingMovies  \
# 0                     No                   No  No internet service
# 1                     No  No internet service  No internet service
# 2                    Yes                  Yes                   No
# 3                     No  No internet service                  Yes
# 4                     No                   No  No internet service
# ..                   ...                  ...                  ...
# 295  No internet service                   No                   No
# 296  No internet service                  Yes                  Yes
# 297                  Yes                   No                  Yes
# 298  No internet service                  Yes                  Yes
# 299                   No  No internet service                  Yes
#
#            Contract PaperlessBilling     PaymentMethod Churn
# 0    Month-to-month              Yes       Credit card   Yes
# 1          Two year               No  Electronic check   Yes
# 2          One year               No     Bank transfer   Yes
# 3    Month-to-month               No  Electronic check    No
# 4          One year               No     Bank transfer   Yes
# ..              ...              ...               ...   ...
# 295        One year              Yes  Electronic check    No
# 296  Month-to-month              Yes      Mailed check   Yes
# 297        Two year               No      Mailed check   Yes
# 298        Two year               No       Credit card    No
# 299  Month-to-month               No  Electronic check   Yes
#
# [300 rows x 16 columns]

# %%
# seperated two dataset merge 
two=[df,dff]

# %%
#merge two files
preprocessed=pd.concat(two,axis=1)

# %%
preprocessed
# Out:
#      SeniorCitizen  tenure  MonthlyCharges  TotalCharges  gender Partner  \
# 0                0       5           27.43        137.15    Male     Yes
# 1                0      42           38.28       1607.76  Female      No
# 2                0      61          106.44       6492.84    Male      No
# 3                1      22           92.49       2034.78    Male      No
# 4                1      21           19.63        412.23    Male     Yes
# ..             ...     ...             ...           ...     ...     ...
# 295              1      61           42.52       2593.72  Female      No
# 296              0      49           22.31       1093.19  Female      No
# 297              0      71           59.57       4229.47    Male      No
# 298              1       1           31.32         31.32    Male     Yes
# 299              1      13           20.50        266.50  Female     Yes
#
#     Dependents PhoneService     MultipleLines InternetService  \
# 0          Yes           No               Yes              No
# 1           No          Yes  No phone service             DSL
# 2           No          Yes  No phone service              No
# 3          Yes          Yes                No              No
# 4          Yes           No                No             DSL
# ..         ...          ...               ...             ...
# 295        Yes           No               Yes             DSL
# 296         No          Yes  No phone service             DSL
# 297        Yes          Yes               Yes             DSL
# 298        Yes          Yes               Yes              No
# 299        Yes          Yes               Yes             DSL
#
#           OnlineSecurity         OnlineBackup     DeviceProtection  \
# 0                     No                  Yes                   No
# 1                    Yes                  Yes                   No
# 2                     No                  Yes                   No
# 3    No internet service  No internet service                  Yes
# 4                     No                   No  No internet service
# ..                   ...                  ...                  ...
# 295                   No  No internet service                  Yes
# 296  No internet service                   No                  Yes
# 297  No internet service                   No                  Yes
# 298                  Yes  No internet service  No internet service
# 299  No internet service  No internet service                  Yes
#
#              TechSupport          StreamingTV      StreamingMovies  \
# 0                     No                   No  No internet service
# 1                     No  No internet service  No internet service
# 2                    Yes                  Yes                   No
# 3                     No  No internet service                  Yes
# 4                     No                   No  No internet service
# ..                   ...                  ...                  ...
# 295  No internet service                   No                   No
# 296  No internet service                  Yes                  Yes
# 297                  Yes                   No                  Yes
# 298  No internet service                  Yes                  Yes
# 299                   No  No internet service                  Yes
#
#            Contract PaperlessBilling     PaymentMethod Churn
# 0    Month-to-month              Yes       Credit card   Yes
# 1          Two year               No  Electronic check   Yes
# 2          One year               No     Bank transfer   Yes
# 3    Month-to-month               No  Electronic check    No
# 4          One year               No     Bank transfer   Yes
# ..              ...              ...               ...   ...
# 295        One year              Yes  Electronic check    No
# 296  Month-to-month              Yes      Mailed check   Yes
# 297        Two year               No      Mailed check   Yes
# 298        Two year               No       Credit card    No
# 299  Month-to-month               No  Electronic check   Yes
#
# [300 rows x 20 columns]

# %%
# File save format
preprocessed.to_csv("churn_preprocess_data.csv",index=False)

# %%
preprocessed
# Out:
#      SeniorCitizen  tenure  MonthlyCharges  TotalCharges  gender Partner  \
# 0                0       5           27.43        137.15    Male     Yes
# 1                0      42           38.28       1607.76  Female      No
# 2                0      61          106.44       6492.84    Male      No
# 3                1      22           92.49       2034.78    Male      No
# 4                1      21           19.63        412.23    Male     Yes
# ..             ...     ...             ...           ...     ...     ...
# 295              1      61           42.52       2593.72  Female      No
# 296              0      49           22.31       1093.19  Female      No
# 297              0      71           59.57       4229.47    Male      No
# 298              1       1           31.32         31.32    Male     Yes
# 299              1      13           20.50        266.50  Female     Yes
#
#     Dependents PhoneService     MultipleLines InternetService  \
# 0          Yes           No               Yes              No
# 1           No          Yes  No phone service             DSL
# 2           No          Yes  No phone service              No
# 3          Yes          Yes                No              No
# 4          Yes           No                No             DSL
# ..         ...          ...               ...             ...
# 295        Yes           No               Yes             DSL
# 296         No          Yes  No phone service             DSL
# 297        Yes          Yes               Yes             DSL
# 298        Yes          Yes               Yes              No
# 299        Yes          Yes               Yes             DSL
#
#           OnlineSecurity         OnlineBackup     DeviceProtection  \
# 0                     No                  Yes                   No
# 1                    Yes                  Yes                   No
# 2                     No                  Yes                   No
# 3    No internet service  No internet service                  Yes
# 4                     No                   No  No internet service
# ..                   ...                  ...                  ...
# 295                   No  No internet service                  Yes
# 296  No internet service                   No                  Yes
# 297  No internet service                   No                  Yes
# 298                  Yes  No internet service  No internet service
# 299  No internet service  No internet service                  Yes
#
#              TechSupport          StreamingTV      StreamingMovies  \
# 0                     No                   No  No internet service
# 1                     No  No internet service  No internet service
# 2                    Yes                  Yes                   No
# 3                     No  No internet service                  Yes
# 4                     No                   No  No internet service
# ..                   ...                  ...                  ...
# 295  No internet service                   No                   No
# 296  No internet service                  Yes                  Yes
# 297                  Yes                   No                  Yes
# 298  No internet service                  Yes                  Yes
# 299                   No  No internet service                  Yes
#
#            Contract PaperlessBilling     PaymentMethod Churn
# 0    Month-to-month              Yes       Credit card   Yes
# 1          Two year               No  Electronic check   Yes
# 2          One year               No     Bank transfer   Yes
# 3    Month-to-month               No  Electronic check    No
# 4          One year               No     Bank transfer   Yes
# ..              ...              ...               ...   ...
# 295        One year              Yes  Electronic check    No
# 296  Month-to-month              Yes      Mailed check   Yes
# 297        Two year               No      Mailed check   Yes
# 298        Two year               No       Credit card    No
# 299  Month-to-month               No  Electronic check   Yes
#
# [300 rows x 20 columns]

# %%
preprocessed.isnull().sum()
# Out:
# SeniorCitizen       0
# tenure              0
# MonthlyCharges      0
# TotalCharges        0
# gender              0
# Partner             0
# Dependents          0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# Churn               0
# dtype: int64
